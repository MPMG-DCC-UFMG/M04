# %% [markdown]
# # Script atual - levantamento de funcionalidades e requisitos

# %% [markdown]
# ## Entradas principais:
#
# 1. Arquivo de licitações
#     - Número da licitação, município, ano, tipo, descrição...
#
# 2. Arquivo de CNPJs licitantes por licitação
#     - Duas colunas: Número da Licitação e CNPJ
#         - O número de licitação se repete para cada CNPJ participante
#
#                 l1 cnpj_1
#                 l1 cnpj_2
#                 ...
#                 l1 cnpj_n
#                 l2 cnpj_k
#                 ...
#
# 3. Arquivo de CNPJs relacionados
#     - Duas colunas: CNPJ_1 e CNPJ_2
#         - Dois CNPJs formam uma observação se existe um vínculo entre eles (especificado na geração do arquivo)

# %% [markdown]
# ## Saídas principais
#
# ### 1. Relatórios .csv utilizados para geração de gráficos e visualizações
#
# - CNPJs_APARECENDO_JUNTOS_EM_LICITACOES.csv
#
#         CNPJ_1
#         CNPJ_2
#         qtdade_vezes_mesma_licitacao
#         qtdade_vezes_cnpj1_participou_licitacoes
#         sem nome (valores entre 0 e 1)
#
# - CNPJs_APARECENDO_JUNTOS_EM_LICITACOES_SUMARIZADO.csv
#
#         CNPJ
#         soma-ocorrencias-com-outros-cnpjs
#         qtdade_licitacoes_cnpj_participou
#         soma-ocorrencias-dividido-por-qtdade-licitacoes
#         detalhe-cnpj
#         detalhe-contagem (se expande em várias colunas: CNJP | int | CNPJ | int ...)
#
# - CNPJs_COM_RELACAO_SOCIETARIA_COMUM-MG.csv
#
#         sem formato tabular, possivelmente sumarizacao estatistica
#
# - CNPJs_COM_RELACAO_SOCIETARIA_COMUM_RAW_MG.csv
#
#         CNPJ
#         qtdade
#         cnpjs com relacao societaria (expande em varias colunas, lista de cnpjs)
#
# - CNPJs_POR_LICITACAO-MG.csv
#
#         sem formato tabular, possivelmente sumarizacao estatistica
#
# - CNPJs_POR_LICITACAO_RAW_MG.csv
#
#         licitacao
#         qtdade
#         cnpjs (expande em varias colunas, lista de cnpjs)
#
# - LICITACOES_POR_MUNICIPIO.csv
#
#         municipio
#         qtdade
#         licitacoes (expande em varias colunas, lista de licitacoes)
#
# - QTDADE_LICITACOES_POR_CNPJ-MG.csv
#
#         sem formato tabular, possivelmente sumarizacao estatistica
#
# - QTDADE_LICITACOES_POR_CNPJ_RAW_MG.csv
#
#         CNPJ
#         qtdade
#         licitacoes (expande em varias colunas, lista de licitacoes)
#
# - RELATORIO_GRAFOS_POR_LICITACAO.csv
#
#         densidade
#         max_clique
#         municipio
#         estado
#         tipo
#         identificador
#         ano
#         descricao
#         valor
#         vertices_clique (expande em varias colunas, lista de cnpjs)
#
# - RELATORIO_GRAFOS_POR_MUNICIPIO.csv
#
#         chave
#         arestas
#         vertices
#         max_clique
#         vertices_clique (expande em varias colunas, lista de cnpjs)

# %% [markdown]
# ### 2. Visualizações dos grafos
#
# #### ... por município:
#
# e.g. Espera Feliz (melhor café do Brasil)

# %%
from IPython.display import Image
Image(filename='/home/pedro/code/trabalho/mpmg_workspace/code_cristiano/grafos/municipios/008-Espera-Feliz.png')

# %% [markdown]
# #### ... por licitação:
#
# e.g. (725223)

# %%
Image(filename='/home/pedro/code/trabalho/mpmg_workspace/code_cristiano/grafos/licitacoes/003-725223..png')
