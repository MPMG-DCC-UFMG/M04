# %% [markdown]
# # Análise relatório 2

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/output/csv/relatorio_2')
#df = df.drop(["Unnamed: 0", "ano", "modalidade", "valor",
#              "vinculo_em_uso", "cnpjs", "municipio"], axis=1)
df.head(5)
# Out:
#    Unnamed: 0   ano municipio tipo_processo_licitatorio  id_licitacao  \
# 0           0  2015    Abaeté         Pregão Presencial        985568
# 1           1  2016    Abaeté         Pregão Presencial        985621
# 2           2  2017    Abaeté         Pregão Presencial        985641
# 3           3  2017    Abaeté         Pregão Eletrônico        985644
# 4           4  2018    Abaeté         Pregão Presencial        985703
#
#           valor  vinculo_em_uso  quantidade_cnpjs  quantidade_vinculos  \
# 0  8.811000e+05               1                 4                    6
# 1  1.106500e+06               1                 3                    1
# 2  1.115230e+05               1                 3                    1
# 3  9.992878e+05               1                19                    1
# 4  2.689026e+05               1                 3                    3
#
#    densidade_grafo  tam_clique_encontrada  \
# 0         1.000000                      4
# ...

# %%
df.sort_values(by=["tam_clique_encontrada"], ascending=False).head(10)
# Out:
#      Unnamed: 0   ano            municipio tipo_processo_licitatorio  \
# 0             0  2015               Abaeté         Pregão Presencial
# 560         560  2018            Jacutinga         Pregão Presencial
# 468         468  2016  Conceição dos Ouros         Pregão Presencial
# 809         809  2015  Conceição dos Ouros         Pregão Presencial
# 800         800  2015              Aguanil         Pregão Presencial
# 402         402  2016            Jacutinga         Pregão Presencial
# 26           26  2017                Araxá         Pregão Presencial
# 406         406  2016       Belo Horizonte         Pregão Eletrônico
# 613         613  2016            Itabirito         Pregão Presencial
# 414         414  2015           Uberlândia         Pregão Eletrônico
#
#      id_licitacao       valor  vinculo_em_uso  quantidade_cnpjs  \
# 0          985568   881100.00               1                 4
# 560        809665   811991.70               1                 8
# ...
